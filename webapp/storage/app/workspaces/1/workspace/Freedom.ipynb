# %%
print("hello world")
# Out:
# hello world

# %%
# !cat data.json | jq '.dataset | .[] | { "title": .title, "theme": .theme, "datasetUrl": [.distribution[].downloadURL ] }'
# Out:
# {
#   "title": "Συνολικά αποτελέσματα ελέγχου ποιότητας νερού - Ιοντικός Έλεγχος και Βαρέα Μέταλλα",
#   "theme": [
#     "Υγεία"
#   ],
#   "datasetUrl": [
#     "https://data.gov.cy/sites/default/files/DW%20-%20ALL%20YEARS%20-%20chemical.csv",
#     "https://data.gov.cy/sites/default/files/%CE%A0%CF%8C%CF%83%CE%B9%CE%BC%CE%BF%20%CE%BD%CE%B5%CF%81%CF%8C%20%CE%B1%CE%BE%CE%B9%CE%BF%CE%BB%CF%8C%CE%B3%CE%B7%CF%83%CE%B7%20%CF%80%CE%B1%CF%81%CE%B1%CE%BC%CE%AD%CF%84%CF%81%CF%89%CE%BD.pdf",
#     "https://data.gov.cy/sites/default/files/DW%202017%20JAN%20-%20JUN%20chemical.xlsx",
#     "https://data.gov.cy/sites/default/files/DW%202017%20JUL%20-%20DEC%20chemical.xlsx"
#   ]
# }
# {
#   "title": "Συνολικά αποτελέσματα ελέγχου ποιότητας νερού - Οργανικοί Ρύποι",
#   "theme": [
#     "Υγεία"
#   ],
#   "datasetUrl": [
#     "https://data.gov.cy/sites/default/files/DW%20-%20ALL%20YEARS%20-%20organic.csv",
# ...

# %%
# !cat data.json | jq '.dataset | .[] '
# Out:
# {
#   "@type": "dcat:Dataset",
#   "accessLevel": "public",
#   "contactPoint": {
#     "fn": "Αγάθη Αναστάση",
#     "hasEmail": "mailto:aanastasi@sgl.moh.gov.cy"
#   },
#   "description": "<p>Συνολικά αποτελέσματα ελέγχου ποιότητας του πόσιμου νερού (εντός και εκτός νομοθετικών ορίων) - Μικροβιολογικός έλεγχος. Για κάθε αποτέλεσμα περιλαμβάνονται τα εξής πεδία:</p>\n<ul>\n<li>Επαρχία (District)</li>\n<li>Κωδικός Ζώνης Παροχής νερού (Zone Code)</li>\n<li>Περιγραφή Ζώνης Παροχής Νερού (Zone Descripton)</li>\n<li>Πόλη/Χωριό (City/Village)</li>\n<li>Ημερομηνία Δειγματοληψίας (Sampling Date)</li>\n<li>Παράμετρος (Parameter)</li>\n<li>Αποτέλεσμα (Result)</li>\n<li>Νομοθετικό όριο (Legal Limit)</li>\n<li>Μονάδα Μέτρησης (Unit)</li>\n<li>Αριθμός δείγματος Γενικού Χημείου (GSL No)</li>\n</ul>\n<p>Επίσης, παρέχονται σε ξεχωριστό αρχείο πρόσθετες βοηθητικές πληροφορίες για κατανόηση και ερμηνεία των παρεχόμενων αποτελεσμάτων.</p>\n",
#   "distribution": [
#     {
# ...
