# %%
import sys
import pandas as pd
from Opendata import Opendata
from ResultSet import ResultSet
op = Opendata('cy')

# %%
op.getDatasets()
# Out:
#                                           downloadURL format  \
# 0   https://data.gov.cy/sites/default/files/DW%20-...    csv
# 1   https://data.gov.cy/sites/default/files/%CE%A0...    pdf
# 2   https://data.gov.cy/sites/default/files/DW%202...   xlsx
# 3   https://data.gov.cy/sites/default/files/DW%202...   xlsx
# 4   https://data.gov.cy/sites/default/files/DW%20-...    csv
# 5   https://data.gov.cy/sites/default/files/%CE%A0...    pdf
# 6   https://data.gov.cy/sites/default/files/DW%202...   xlsx
# 7   https://data.gov.cy/sites/default/files/DW%202...   xlsx
# 8   https://data.gov.cy/sites/default/files/DW%20-...    csv
# 9   https://data.gov.cy/sites/default/files/%CE%95...    pdf
# 10  https://data.gov.cy/sites/default/files/%CE%A0...    pdf
# 11  https://data.gov.cy/sites/default/files/DW%202...   xlsx
# 12  https://data.gov.cy/sites/default/files/DW%202...   xlsx
# 13  https://data.gov.cy/sites/default/files/%CE%9A...    kmz
# ...

# %%
resource = op.getResource('https://data.gov.cy/api/action/datastore/search.json?resource_id=e4116df6-5cfb-473a-949b-6a74ba8cc54a&limit=15')

# %%
data = resource.toDataFrame
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-b78f074cd5ec> in <module>()
# ----> 1 data = resource.toDataFrame
#
# AttributeError: 'ResultSet' object has no attribute 'toDataFrame'

# %%
type(resource)
# Out:
# ResultSet.ResultSet
